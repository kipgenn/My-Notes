# %% [markdown]
# ##Converting A DF to A series

# %%
#column
mseries1 = data['column name']
mseries2 = data.iloc[:, 0] #or whatever index\

#row 
mseries3 = data.iloc['row_name']
mseries4 = data.iloc[0] #or whatever row index

# %%
##ReNaming or Swapping Objects

# %%
#in col1 swap all YES with 1 and all NO with 0
df['col1'] = df['col1'].map({"YES":1, "NO":0})

# %% [markdown]
# ##Dealing with Dates

# %%
# 1. Convert to Datetime
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
# 2. Extract Features
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
# 3. Drop Original
df.drop('Date', axis=1, inplace=True)
